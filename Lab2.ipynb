# %% [markdown]
# # Laboratorio 2: Python para Ciencia de Datos 👾
#
# IA7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2026
#
# ---

# %% [markdown]
# ### Cuerpo Docente
#
# - Profesor: Pablo Badilla y Ignacio Nuñez
# - Auxiliar: Sofía Chávez
# - Ayudantes: Javiera Arévalo, Tamara Carrasco, Ignacio Reyes
#
# ### Objetivos del lab
#
# - Reconocer la estructura de un proyecto Python y el rol de `main.py` como punto de entrada.
# - Definir clases con atributos, métodos y constructor, usando type hints.
# - Aplicar los principios de la programación orientada a objetos: herencia, abstracción, encapsulación y polimorfismo.
# - Manejar excepciones y definir excepciones propias.
# - Construir, en paralelo al notebook, un mini proyecto que detecta situaciones de riesgo en un cultivo.

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Vicente Carrasco
# - Nombre de alumno 2: Vicente Anguita

# %% [markdown]
# ---
#
# ## Estructura de Proyecto

# %% [markdown]
# Hasta ahora todo el código de este curso vivió dentro de un notebook: lo escribieron en una celda, lo ejecutaron, y ahí quedó. A partir de este laboratorio van a organizar código en archivos y carpetas, como en cualquier proyecto real — el mismo tipo de estructura que ya empezaron a armar en el Laboratorio 1 con `pyproject.toml`, `uv` y Ruff.

# %% [markdown]
# ### Anatomía de un proyecto Python

# %% [markdown]
# Este es el árbol de carpetas que van a tener en su repositorio del curso al terminar este laboratorio:

# %% [markdown]
# ```
# IA7202/ (Su repo del curso)
# ├── .git/
# ├── .github/
# │   └── workflows/
# │       └── lint.yml
# ├── labs/
# │   ├── lab_1/
# │   └── lab_2/
# |       ├── src/
# |       |   └── paquete/
# |       ├── tests/
# |       ├── main.py
# |       └── README.md
# ├── .gitignore
# ├── .pre-commit-config.yaml
# ├── main.py
# ├── pyproject.toml
# ├── README.md
# └── uv.lock
# ```

# %% [markdown]
# Del Laboratorio 1 ya conocen la mayoría de estos elementos:
#
# | Elemento | Qué es |
# |---|---|
# | `.git/` | El historial de commits de su repositorio |
# | `.github/workflows/lint.yml` | El workflow que corre las validaciones en CI |
# | `labs/` | Los laboratorios de cada semana |
# | `.gitignore` | Los archivos que Git debe ignorar (como `.venv/`) |
# | `.pre-commit-config.yaml` | Los hooks que se ejecutan antes de cada commit |
# | `pyproject.toml` | La configuración del proyecto y sus dependencias |
# | `README.md` | La documentación del proyecto |
# | `uv.lock` | La resolución exacta de esas dependencias |

# %% [markdown]
# Lo nuevo en este laboratorio son dos carpetas y un archivo:
#
# | Elemento | Qué es |
# |---|---|
# | `main.py` | El archivo que se ejecuta cuando corren el proyecto como programa |
# | `src/mi_paquete/` | El código fuente reutilizable |
# | `tests/` | Las pruebas que verifican que el código funciona |

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — módulo, paquete y punto de entrada</strong>
#   Un <strong>módulo</strong> es un archivo <code>.py</code> que contiene código reutilizable. Un <strong>paquete</strong> es una carpeta que organiza módulos relacionados. El <strong>punto de entrada</strong> es el archivo desde el cual se inicia el programa; en este proyecto es <code>main.py</code>.
# </div>

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta</strong>
#   Si quisieran reutilizar una función que escribieron en un laboratorio anterior, ¿en cuál de estas carpetas la pondrían?
# </div>

# %% [markdown]
# ### Respuesta:
# Lo incluría en la carpeta de scr/mi paquete/, ya que es ahí está el código fuente reutizible, en el que hay funciones y clases que pueden ser utilizadas posteriormente, y que se pueden importar desde otros archivos.

# %% [markdown]
# ### ¿Qué es `main.py`?

# %% [markdown]
# `main.py` es el **punto de entrada** de su proyecto: el archivo que ejecutan cuando quieren correr el proyecto como programa, en vez de abrir un notebook. Ya tienen uno en la raíz de su repositorio — lo generó `uv init` en el Laboratorio 1 — y hasta ahora no lo habían tocado. Este es su contenido actual:
#
# ```python
# def main():
#     print("Hello from mds7202-v2!")
#
#
# if __name__ == "__main__":
#     main()
# ```

# %% [markdown]
# La parte que probablemente no reconocen es `if __name__ == "__main__":`.
#
# `__name__` es una variable especial que Python define automáticamente en cada archivo. Vale `"__main__"` cuando ese archivo es el que se ejecutó directamente, y vale el nombre del módulo cuando el archivo fue importado desde otro lugar.
#
# Ese `if` aprovecha la diferencia para separar dos cosas: el código que **define** funciones y clases, que debe estar disponible siempre, del código que **se ejecuta** al correr el programa, que solo debería dispararse cuando alguien ejecuta ese archivo a propósito.

# %% [markdown]
# <!-- PREGUNTA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta</strong>
#   Si en `main.py` no existiera el `if __name__ == "__main__":` y ustedes hicieran `import main` desde otro archivo, ¿qué pasaría?
# </div>

# %% [markdown]
# ### Respuesta:
# Si es que importmos `main.py`, Python ejecutaría también el código que estuviera escrito directamente en el archivo. El `if __name__ == "__main__":` permite que el código destinado a iniciar el programa se ejecute solamente cuando `main.py` se ejecuta directamente y no cuando se importa como módulo.

# %% [markdown]
# ---
#
# ## Mini proyecto
#
# En base a los contenidos de este Notebook, tendrán que trabajar un mini proyecto en paralelo. El contexto y las instrucciones las podrán encontrar en el archivo `Proyecto.md`. A medida que vayas avanzando en este Notebook se te indicará cuándo tienes que avanzar en el Mini Proyecto.
#
# La entrega del laboratorio incluye tanto el Notebook como el Mini Proyecto y sus respectivos archivos como una PR en el repositorio de Github.

# %% [markdown]
# <!-- EVALUACIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #8b5cf6; background:rgba(139,92,246,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📊 Evaluación</strong>
#   El mini proyecto tiene un máximo de <strong>6,0 puntos</strong>: 5,4 puntos por las etapas prácticas y 0,6 puntos por las tres preguntas de salida. La nota se calcula como <code>1,0 + puntaje obtenido</code>.
# </div>

# %% [markdown]
# <!-- MINI PROYECTO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f0883e; background:rgba(240,136,62,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛠️ Mini Proyecto — Etapa 1</strong>
#   Ya vieron cómo se organiza un proyecto y para qué sirve <code>main.py</code>. Vayan a <code>Proyecto.md</code> y resuelvan la <strong>Etapa 1 — Estructura del proyecto</strong>: crear las carpetas, dejar los datos en su lugar y dejar <code>main.py</code> corriendo.
# </div>

# %% [markdown]
# ## Programación Orientada a Objetos
#
# La programación orientada a objetos permite agrupar datos y comportamientos
# relacionados dentro de objetos. Para mantener un solo hilo conductor, desde
# esta sección trabajaremos con un automóvil y sus variantes.
#
# Más adelante aplicaremos las mismas ideas al mini proyecto AgroAlerta:
# Auto será un ejemplo didáctico y Sensor será la aplicación del concepto.

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #2f81f7; background:rgba(47,129,247,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Idea clave</strong>
#   Usaremos siempre el mismo modelo: un Auto base, un AutoElectrico y un AutoCombustion. Cada etapa agregará una idea nueva sobre ese modelo.
# </div>

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — clase, objeto y comportamiento</strong>
#   Una <strong>clase</strong> es una definición que describe qué datos y comportamientos tendrán sus instancias. Un <strong>objeto</strong> es una instancia concreta de esa clase. Los datos se guardan en <strong>atributos</strong> y las acciones se expresan mediante <strong>métodos</strong>.
# </div>

# %% [markdown]
# ## Clases en Python
#
# Una clase define la estructura que tendrán sus objetos. Primero podemos crear
# una clase vacía y luego agregarle atributos, métodos y reglas.

# %%
class Auto:
    pass


auto = Auto()
print(type(auto).__name__)

# %% [markdown]
# ### Atributos, constructor y métodos
#
# El constructor permite crear autos con un estado inicial. En este ejemplo
# guardamos la marca, el modelo, la velocidad máxima y la velocidad actual.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — constructor, atributos y métodos</strong>
#   El <strong>constructor</strong> es el método <code>__init__</code>, que se ejecuta al crear un objeto y deja listo su estado inicial. Un <strong>atributo</strong> es un dato asociado al objeto, como <code>marca</code>. Un <strong>método</strong> es una función definida dentro de la clase, como <code>acelerar</code>, que puede leer o modificar ese estado.
# </div>

# %%
class Auto:
    def __init__(
        self,
        marca: str,
        modelo: str,
        velocidad_maxima: float,
    ) -> None:
        self.marca = marca
        self.modelo = modelo
        self.velocidad_maxima = velocidad_maxima
        self._velocidad = 0.0

    def acelerar(self, incremento: float) -> None:
        self._velocidad += incremento

    def frenar(self, decremento: float) -> None:
        self._velocidad -= decremento


auto = Auto("Toyota", "Yaris", 180)
auto.acelerar(30)
auto.frenar(10)

print(auto.marca, auto.modelo)
print(auto.velocidad_maxima)
print(auto._velocidad)

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #d29922; background:rgba(210,153,34,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">⚠️ Aviso</strong>
#   El guion bajo de _velocidad comunica que es un detalle interno. Todavía es posible acceder a él, pero el código externo no debería depender de ese atributo.
# </div>

# %% [markdown]
# ### Type hints
#
# Los type hints documentan qué datos espera cada método y qué valor devuelve.
# No impiden por sí solos que alguien entregue otro tipo de dato, pero hacen más
# clara la interfaz del objeto.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — type hints</strong>
#   Los <strong>type hints</strong> son anotaciones que indican los tipos esperados para parámetros y retornos. Sirven como documentación y ayudan a las herramientas de desarrollo, pero Python no los convierte automáticamente en validaciones durante la ejecución.
# </div>

# %%
def describir_auto(auto: Auto) -> str:
    return f"{auto.marca} {auto.modelo}: {auto._velocidad} km/h"


print(describir_auto(auto))

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #8957e5; background:rgba(137,87,229,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🧪 Comprobación</strong>
#   Cree un Auto con los mismos argumentos, acelérelo en 30 km/h y frénelo en 10 km/h. La velocidad final debe ser 20 km/h.
# </div>

# %%
auto = Auto("Toyota", "Yaris", 180)

auto.acelerar(30)
auto.frenar(10)

assert auto._velocidad == 20

# %% [markdown]
# <!-- MINI PROYECTO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f0883e; background:rgba(240,136,62,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛠️ Mini Proyecto — Etapa 2</strong>
#   Con clases, constructor, métodos y type hints, resuelvan la <strong>Etapa 2 — La clase Sensor</strong>.
# </div>

# %% [markdown]
# ## Herencia
#
# La herencia permite crear clases nuevas a partir de una clase base. Las clases
# derivadas reutilizan los atributos y métodos comunes, y pueden agregar o
# sobrescribir comportamientos.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — herencia y <code>super()</code></strong>
#   La <strong>herencia</strong> permite que una subclase reutilice la estructura y los comportamientos de una clase base. <code>super()</code> permite acceder a la implementación de la clase base, especialmente para ejecutar su constructor, sin repetir ese código.
# </div>

# %%
class AutoElectrico(Auto):
    def fuente_energia(self) -> str:
        return "batería"


class AutoCombustion(Auto):
    def fuente_energia(self) -> str:
        return "combustible"


electrico = AutoElectrico("Tesla", "Model 3", 200)
combustion = AutoCombustion("Suzuki", "Swift", 180)

print(electrico.fuente_energia())
print(combustion.fuente_energia())

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #2f81f7; background:rgba(47,129,247,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Idea clave</strong>
#   Las clases derivadas reutilizan lo común de Auto, pero cada una puede definir su propia fuente de energía.
# </div>

# %% [markdown]
# La clase base concentra lo que todos los autos comparten. Una subclase
# solo debe agregar o redefinir lo que la hace distinta.

# %% [markdown]
# <!-- MINI PROYECTO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f0883e; background:rgba(240,136,62,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛠️ Mini Proyecto — Etapa 3</strong>
#   Ahora que saben heredar, resuelvan la <strong>Etapa 3 — Herencia y sensores concretos</strong>.
# </div>

# %% [markdown]
# ## Abstracción y encapsulación
#
# Una clase abstracta define la interfaz que sus subclases deben cumplir. Para
# los autos, toda variante debe informar cuál es su fuente de energía, pero la
# clase base no puede decidir esa respuesta por sí sola.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — abstracción, encapsulación y propiedad</strong>
#   La <strong>abstracción</strong> define qué debe ofrecer un objeto sin obligar a mostrar cómo lo implementa. La <strong>encapsulación</strong> reúne el estado y sus operaciones, y recomienda no depender directamente de los detalles internos. Una <strong>propiedad</strong> permite consultar o modificar un atributo mediante una interfaz como si fuera un atributo, manteniendo la lógica dentro de la clase.
# </div>

# %%
from abc import ABC, abstractmethod


class Auto(ABC):
    def __init__(
        self,
        marca: str,
        modelo: str,
        velocidad_maxima: float,
    ) -> None:
        self.marca = marca
        self.modelo = modelo
        self.velocidad_maxima = velocidad_maxima
        self._velocidad = 0.0

    @abstractmethod
    def fuente_energia(self) -> str: ...

    @property
    def velocidad(self) -> float:
        return self._velocidad

    def acelerar(self, incremento: float) -> None:
        self._velocidad += incremento

    def frenar(self, decremento: float) -> None:
        self._velocidad -= decremento


class AutoElectrico(Auto):
    def fuente_energia(self) -> str:
        return "batería"


class AutoCombustion(Auto):
    def fuente_energia(self) -> str:
        return "combustible"


electrico = AutoElectrico("Tesla", "Model 3", 200)
combustion = AutoCombustion("Suzuki", "Swift", 180)

electrico.acelerar(30)
combustion.acelerar(30)

print(electrico.velocidad)
print(combustion.velocidad)

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #d29922; background:rgba(210,153,34,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">⚠️ Aviso</strong>
#   Auto no se puede instanciar porque tiene un método abstracto. Las subclases sí se pueden crear cuando implementan fuente_energia.
# </div>

# %%
try:
    Auto("Toyota", "Yaris", 180)
except TypeError as error:
    print(f"No se puede crear Auto: {error}")

# %% [markdown]
# La propiedad velocidad entrega una forma simple de consultar el estado
# del auto sin exponer directamente cómo se guarda internamente. La convención
# _protegida no es una barrera de seguridad: es una señal para quien usa la clase.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — atributos protegidos y privados</strong>
#   En Python, un atributo con un prefijo <code>_</code> se considera <strong>protegido por convención</strong>: se puede acceder, pero el código externo debería tratarlo como un detalle interno. Un prefijo doble, como <code>__velocidad</code>, activa un mecanismo de renombrado interno (*name mangling*); tampoco constituye una barrera de seguridad.
# </div>

# %% [markdown]
# <!-- MINI PROYECTO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f0883e; background:rgba(240,136,62,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛠️ Mini Proyecto — Etapa 4</strong>
#   Con clases abstractas, atributos protegidos y propiedades, resuelvan la <strong>Etapa 4 — Abstracción, encapsulación y propiedades</strong>.
# </div>

# %% [markdown]
# <!-- PREGUNTA DE SALIDA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta de salida 1 (0,2 puntos)</strong>
#   ¿Qué comunica el prefijo _ en un atributo si todavía es posible acceder a él desde fuera de la clase?
# </div>

# %% [markdown]
# <code>Escribe tu respuesta aquí:</code>
#
# El prefijo `_` comunica por convención que el atributo es protegido y forma parte de la implementación interna de la clase. Aunque Python permite acceder a él desde fuera, el código externo no debería depender directamente de ese atributo. Es más como una advertencia para otras personas trabajando y que vean el código.

# %% [markdown]
# ## Polimorfismo
#
# Una función polimórfica trabaja con objetos distintos siempre que todos
# respondan al método que la función necesita.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — polimorfismo</strong>
#   El <strong>polimorfismo</strong> permite que una misma función trabaje con objetos de clases distintas mediante una interfaz común. La función se concentra en qué operación necesita, no en preguntar de qué tipo concreto es cada objeto.
# </div>

# %%
def describir_fuentes(autos: list[Auto]) -> None:
    for auto in autos:
        print(f"{auto.modelo}: {auto.fuente_energia()}")


autos = [electrico, combustion]
describir_fuentes(autos)

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #2f81f7; background:rgba(47,129,247,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Idea clave</strong>
#   describir_fuentes no pregunta si el objeto es eléctrico o de combustión. Solo llama a fuente_energia, que forma parte de la interfaz común.
# </div>

# %% [markdown]
# <!-- PREGUNTA DE SALIDA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta de salida 2 (0,2 puntos)</strong>
#   Si se agrega un sensor de lluvia, ¿qué archivo debe modificarse y qué parte de contar_riesgos debería permanecer intacta?
# </div>

# %% [markdown]
# <code>Escribe tu respuesta aquí:</code>
#
# Debería modificarse el archivo `sensores.py`, que está en la carpeta `src/agroalerta/`, en el que se agrega el nuevo sensor de lluvia. No se debería modificar el código de  `contar_riesgos`, ya que trabaja de forma genérica con cualquier objeto Sensor: usa `sensor.nombre` para identificarlo y `sensor.es_riesgo(valor)` para determinar si una lectura representa riesgo. Por lo tanto, mientras el nuevo sensor implemente correctamente esos elementos, debería funcionar bien.

# %% [markdown]
# <!-- MINI PROYECTO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f0883e; background:rgba(240,136,62,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛠️ Mini Proyecto — Etapa 5</strong>
#   Resuelvan la <strong>Etapa 5 — Polimorfismo y reporte</strong>.
# </div>

# %% [markdown]
# ## Excepciones
#
# Una excepción permite comunicar que una operación no puede completarse
# correctamente. Seguiremos usando Auto para distinguir una velocidad válida de
# una velocidad imposible.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — excepción, <code>raise</code> y <code>try/except</code></strong>
#   Una <strong>excepción</strong> es un objeto que comunica que ocurrió una situación que impide continuar normalmente. <code>raise</code> la lanza; <code>try</code> delimita el código que podría fallar y <code>except</code> define cómo responder a un tipo de error específico.
# </div>

# %%
class VelocidadInvalidaError(Exception):
    pass


def validar_velocidad(auto: Auto, velocidad: float) -> None:
    if velocidad < 0 or velocidad > auto.velocidad_maxima:
        raise VelocidadInvalidaError(
            f"La velocidad debe estar entre 0 y {auto.velocidad_maxima} km/h"
        )


electrico = AutoElectrico("Tesla", "Model 3", 200)

try:
    validar_velocidad(electrico, 250)
except VelocidadInvalidaError as error:
    print(f"Velocidad inválida: {error}")

# %% [markdown]
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #2f81f7; background:rgba(47,129,247,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📌 Idea clave</strong>
#   Una excepción distingue entre una operación válida y una operación que no puede producir un resultado confiable.
# </div>

# %% [markdown]
# <!-- AVISO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #d29922; background:rgba(210,153,34,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">⚠️ Aviso</strong>
#   El <code>except</code> nombra el tipo de error que se quiere manejar. Escribir <code>except Exception</code> atrapa también errores que no tienen nada que ver, como un nombre mal escrito, y los esconde.
# </div>

# %% [markdown]
# <!-- PREGUNTA DE SALIDA -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #58a6ff; background:rgba(88,166,255,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">❓ Pregunta de salida 3 (0,2 puntos)</strong>
#   Complete la celda siguiente y ejecútela. Luego responda: ¿por qué conviene que <code>validar_velocidad</code> <em>levante</em> una excepción, en lugar de devolver <code>False</code> o de imprimir el mensaje ella misma?
# </div>

# %%
# Complete `acelerar_seguro`: debe llamar a `validar_velocidad` dentro de un
# try/except y acelerar solo si la velocidad resultante es válida. Si no lo es,
# debe avisar con un print y dejar la velocidad intacta.


def acelerar_seguro(auto: Auto, incremento: float) -> None:
    try:
        validar_velocidad(auto, auto.velocidad + incremento)
        auto.acelerar(incremento)
    except VelocidadInvalidaError:
        print("Velocidad no es válida")


auto_demo = AutoElectrico("Tesla", "Model 3", 200)

acelerar_seguro(auto_demo, 120)  # válido: la velocidad queda en 120
acelerar_seguro(auto_demo, 120)  # inválido: 240 supera la velocidad máxima

print(auto_demo.velocidad)  # debe imprimir 120.0

# %% [markdown]
# <code>Escribe tu respuesta aquí:</code>
#
# Conviene que `validar_velocidad` levante una excepción porque permite separar la validación del manejo del error. La función se encarga de detectar si la velocidad es inválida, mientras que quien la utiliza decide qué hacer mediante try/except. Esto hace que la función sea más reutilizable y evita depender de devolver False o de imprimir el mensaje directamente

# %% [markdown]
# ## Testing y testing unitario
#
# El <strong>testing</strong> consiste en ejecutar comprobaciones para buscar errores y confirmar que el programa cumple el comportamiento esperado. En este laboratorio usaremos <code>pytest</code> para descubrir y ejecutar las pruebas ubicadas en <code>tests/</code>.
#
# El <strong>testing unitario</strong> verifica una pieza pequeña y aislada del programa, por ejemplo, un método de una clase o una función. Una prueba debe tener un caso claro, una acción y una comprobación del resultado.

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — testing unitario</strong>
#   Una <strong>prueba unitaria</strong> comprueba un comportamiento pequeño sin depender de todo el sistema. Por ejemplo, podemos probar por separado que un auto eléctrico informe "batería" o que un sensor de temperatura reconozca una situación riesgosa.
# </div>

# %% [markdown]
# <!-- DEFINICIÓN -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #3fb950; background:rgba(63,185,80,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">📖 Definición — <code>assert</code></strong>
#   <code>assert</code> verifica que una expresión sea verdadera. Si lo es, la prueba continúa; si es falsa, Python lanza <code>AssertionError</code> y pytest marca la prueba como fallida. La condición debe expresar el resultado que esperamos observar.
# </div>

# %%
auto_prueba = AutoElectrico("Tesla", "Model 3", 200)

assert auto_prueba.fuente_energia() == "batería"
auto_prueba.acelerar(30)
assert auto_prueba.velocidad == 30

print("Las comprobaciones pasaron")

# %% [markdown]
# ### Una prueba unitaria con pytest
#
# Las pruebas se escriben como funciones cuyo nombre comienza con <code>test_</code>. Dentro de ellas, <code>assert</code> expresa el resultado esperado. Al ejecutar <code>uv run pytest</code>, pytest busca automáticamente esos archivos y funciones.
#
# En AgroAlerta, por ejemplo, una prueba unitaria tendrá esta forma:
#
# ```python
# def test_temperatura_bajo_cero_es_riesgo():
#     sensor = SensorTemperatura(0, 40)
#
#     assert sensor.es_riesgo(-2) is True
# ```
#
# Para comprobar que una operación levanta una excepción se puede usar <code>pytest.raises</code>. Con el ejemplo de los autos:
#
# ```python
# def test_velocidad_sobre_el_maximo_levanta_error():
#     auto = AutoElectrico("Tesla", "Model 3", 200)
#
#     with pytest.raises(VelocidadInvalidaError):
#         validar_velocidad(auto, 250)
# ```
#
# La prueba no debe limitarse a ejecutar el código: debe afirmar qué resultado o excepción se esperaba.

# %% [markdown]
# <!-- MINI PROYECTO -->
# <div style="padding:16px 20px; margin:16px 0; border-left:4px solid #f0883e; background:rgba(240,136,62,.12); color:inherit; border-radius:4px;">
#
#   <strong style="display:block; margin-bottom:8px;">🛠️ Mini Proyecto — Etapas 6 y 7</strong>
#   Ya terminaron el notebook. Cierren el proyecto con la <strong>Etapa 6 — Orquestador</strong>, que junta todas las piezas en <code>main.py</code>, y la <strong>Etapa 7 — Pruebas automáticas</strong>.
# </div>
